# %%
import sys 
# !{sys.executable} -m pip install pulp 

import pulp
# Out:
# ...
#   Using cached PuLP-2.4-py3-none-any.whl (40.6 MB)
# ...
#   Using cached amply-0.1.4-py3-none-any.whl (16 kB)
# ...
#   Using cached docutils-0.17.1-py2.py3-none-any.whl (575 kB)
# ...

# %%
m1 = pulp.LpVariable("m1", lowBound = 0) # Catholic Charities Men's Hostel (males only)
m2 = pulp.LpVariable("m2", lowBound = 0) # Covenant House (males separated from females)
m3 = pulp.LpVariable("m3", lowBound = 0) # Belkin House (males separated from females and youth)
m4 = pulp.LpVariable("m4", lowBound = 0) # Anchor of Hope (male only)
m5 = pulp.LpVariable("m5", lowBound = 0) # The Beacon (male only)
m6 = pulp.LpVariable("m6", lowBound = 0) # Crosswalk (males separated from females)
m7 = pulp.LpVariable("m7", lowBound = 0) # First United Church (males separated from females)
m8 = pulp.LpVariable("m8", lowBound = 0) # The Haven (males only)
m9 = pulp.LpVariable("m9", lowBound = 0) # Union Gospel Mission (males only)
m10 = pulp.LpVariable("m10", lowBound = 0) # Aboriginal Shelter (males only)
m11 = pulp.LpVariable("m11", lowBound = 0) # Sutherland Shelter (males only)
m12 = pulp.LpVariable("m12", lowBound = 0) # UGM Emergency Shelter for Men (males only)
m13 = pulp.LpVariable("m13", lowBound = 0) # First Baptist Church (all genders)
m14 = pulp.LpVariable("m14", lowBound = 0) # Grandview Calvary Baptist Church (all genders)
m15 = pulp.LpVariable("m15", lowBound = 0) # Lookout Downtown (Al Mitchell Place) (all genders)
m16 = pulp.LpVariable("m16", lowBound = 0) # Tenth Avenue Church (EWR) (all genders)
m17 = pulp.LpVariable("m17", lowBound = 0) # Yukon Shelter (all genders)
m18 = pulp.LpVariable("m18", lowBound = 0) # Triage (all genders)
m19 = pulp.LpVariable("m19", lowBound = 0) # New Fountain (all genders)
m20 = pulp.LpVariable("m20", lowBound = 0) # Cascade Church (all genders)
m21 = pulp.LpVariable("m21", lowBound = 0) # Community Builders Temp (Metson Winter) (EWR) (all genders)
m22 = pulp.LpVariable("m22", lowBound = 0) # First Avenue Temporary Shelter (all genders)
m23 = pulp.LpVariable("m23", lowBound = 0) # Hornby Street Shelter (temp) (all genders)
m24 = pulp.LpVariable("m24", lowBound = 0) # Vi Fineday Family Shelter Society (all genders)
m25 = pulp.LpVariable("m25", lowBound = 0) # The Gathering Place (all genders)
m26 = pulp.LpVariable("m26", lowBound = 0) # Langara YMCA (all genders)
m27 = pulp.LpVariable("m27", lowBound = 0) # North Shore EWR (all genders)
m28 = pulp.LpVariable("m28", lowBound = 0) # Evelyne Saller Centre EWR (all genders)

f1 = pulp.LpVariable("f1", lowBound = 0) # Covenant House (females separated from males)
f2 = pulp.LpVariable("f2", lowBound = 0) # Crosswalk (females separated from males)
f3 = pulp.LpVariable("f3", lowBound = 0) # First United Church (females separated from males)
f4 = pulp.LpVariable("f4", lowBound = 0) # Women's Emergency Shelter (412 Shelter) (females only)
f5 = pulp.LpVariable("f5", lowBound = 0) # The Sisterhood (females only)
f6 = pulp.LpVariable("f6", lowBound = 0) # Powell Place Shelter For Women (EWR) (females only)
f7 = pulp.LpVariable("f7", lowBound = 0) # SistersShelter (Atira) (females only)
f8 = pulp.LpVariable("f8", lowBound = 0) # First Baptist Church (all genders)
f9 = pulp.LpVariable("f9", lowBound = 0) # Grandview Calvary Baptist Church (all genders)
f10 = pulp.LpVariable("f10", lowBound = 0) # Lookout Downtown (Al Mitchell Place) (all genders)
f11 = pulp.LpVariable("f11", lowBound = 0) # Tenth Avenue Church (EWR) (all genders)
f12 = pulp.LpVariable("f12", lowBound = 0) # Yukon Shelter (all genders)
f13 = pulp.LpVariable("f13", lowBound = 0) # Triage (all genders)
f14 = pulp.LpVariable("f14", lowBound = 0) # New Fountain (all genders) 
f15 = pulp.LpVariable("f15", lowBound = 0) # Cascade Church (all genders)
f16 = pulp.LpVariable("f16", lowBound = 0) # Community Builders Temp (Metson Winter) (EWR) (all genders)
f17 = pulp.LpVariable("f17", lowBound = 0) # First Avenue Temporary Shelter (all genders)
f18 = pulp.LpVariable("f18", lowBound = 0) # Hornby Street Shelter (temp) (all genders)
f19 = pulp.LpVariable("f19", lowBound = 0) # Vi Fineday Family Shelter Society (all genders)
f20 = pulp.LpVariable("f20", lowBound = 0) # The Gathering Place (all genders) 
f21 = pulp.LpVariable("f21", lowBound = 0) # Langara YMCA (all genders)
f22 = pulp.LpVariable("f22", lowBound = 0) # North Shore EWR (all genders)
f23 = pulp.LpVariable("f23", lowBound = 0) # Evelyne Saller Centre EWR (all genders)
f24 = pulp.LpVariable("f24", lowBound = 0) # Belkin House (females and youth only)
f25 = pulp.LpVariable("f25", lowBound = 0) # Springhouse (females and youth only)

y1 = pulp.LpVariable("y1", lowBound = 0) # Dusk to Dawn-Directions Youth Centre (youth only)
y2 = pulp.LpVariable("y2", lowBound = 0) # Aboriginal Youth Safehouse (ASH) (youth only)
y3 = pulp.LpVariable("y3", lowBound = 0) # Marc's Place (youth only)
y4 = pulp.LpVariable("y4", lowBound = 0) # FSGV Safe House (youth only)
y5 = pulp.LpVariable("y5", lowBound = 0) # Belkin House (youth and females only)
y6 = pulp.LpVariable("y6", lowBound = 0) # Springhouse (youth and females only)



optimum = pulp.LpProblem("max", pulp.LpMaximize) 
optimum += m1 + m2 + m3 + m4 + m5 + m6 + m7 + m8 + m9 + m10 + m11 + m12 + m13 + m14 + m15 + m16 + m17 + m18 + m19 + m20 + m21 + m22 + m23 + m24 + m25 + m26 + m27 + m28 + f1 + f2 + f3 + f4 + f5 + f6 + f7 + f8 + f9 + f10 + f11 + f12 + f13 + f14 + f15 + f16 + f17 + f18 + f19 + f20 + f21 + f22 + f23 + f24 + f25 + y1 + y2 + y3 + y4 + y5 + y6, "objective function"
# Shelters that provide beds for only adults who self-identify as male 
optimum += m1 <= 85, "first constraint" 
optimum += m2 <= 35, "second constraint"
optimum += m3 <= 36, "third constraint" 
optimum += m4 <= 28, "fourth constraint" 
optimum += m5 <= 60, "fifth constraint"
optimum += m6 <= 32, "sixth constraint"
optimum += m7 <= 40, "seventh constraint"
optimum += m8 <= 40, "eighth constraint"
optimum += m9 <= 100, "ninth constraint"
optimum += m10 <= 50, "tenth constraint"
optimum += m11 <= 30, "eleventh constraint"
optimum += m12 <= 72, "twelfth constraint"
# Shelters that provide beds for only adults who self-identify as female 
optimum += f1 <= 28, "thirteenth constraint" 
optimum += f2 <= 4, "fourteenth constraint"
optimum += f3 <= 20, "fifteenth constraint"
optimum += f4 <= 57, "sixteenth constraint"
optimum += f5 <= 21, "seventeenth constraint"
optimum += f6 <= 52, "eighteenth constraint"
optimum += f7 <= 16, "nineteenth constraint"
# Shelters that provide beds for only youths 
optimum += y1 <= 12, "twentieth constraint"
optimum += y2 <= 2, "twenty-first constraint"
optimum += y3 <= 1, "twenty-second constraint"
optimum += y4 <= 3, "twenty-third constraint"
# Shelters that provide beds for adults
optimum += m13 + f8 <= 22, "twenty-fourth constraint"
optimum += m14 + f9 <= 20, "twenty-fifth constraint"
optimum += m15 + f10 <= 75, "twenty-sixth constraint"
optimum += m16 + f11 <= 20, "twenty-seventh constraint"
optimum += m17 + f12 <= 72, "twenty-eighth constraint"
optimum += m18 + f13 <= 29, "twenty-ninth constraint"
optimum += m19 + f14 <= 75, "thirtieth constraint"
optimum += m20 + f15 <= 10, "thirty-first constraint"
optimum += m21 + f16 <= 40, "thirty-second constraint"
optimum += m22 + f17 <= 40, "thirty-third constraint"
optimum += m23 + f18 <= 40, "thirty-fourth constraint"
optimum += m24 + f19 <= 18, "thirty-fifth constraint"
optimum += m25 + f20 <= 20, "thirty-sixth constraint"
optimum += m26 + f21 <= 20, "thirty-seventh constraint"
optimum += m27 + f22 <= 12, "thirty-eighth constraint"
optimum += m28 + f23 <= 55, "thirty-ninth constraint"
# Shelters that provide beds for youths and adults who self-identify as female 
optimum += f24 + y5 <= 29, "fourtieth constraint"
optimum += f25 + y6 <= 34, "fourty-first constraint"
# Total number of homeless people in Vancouver
optimum += m1 + m2 + m3 + m4 + m5 + m6 + m7 + m8 + m9 + m10 + m11 + m12 + m13 + m14 + m15 + m16 + m17 + m18 + m19 + m20 + m21 + m22 + m23 + m24 + m25 + m26 + m27 + m28 <= 1570, "fourty-second constraint" # Total number of homless adults who self-identify as male
optimum += f1 + f2 + f3 + f4 + f5 + f6 + f7 + f8 + f9 + f10 + f11 + f12 + f13 + f14 + f15 + f16 + f17 + f18 + f19 + f20 + f21 + f22 + f23 + f24 + f25 <= 546, "fourty-third constraint" # Total number of homless adults who self-identify as female
optimum += y1 + y2 + y3 + y4 + y5 + y6 == 54, "fourty-fourth constraint" # Total number of homless youth (under the age of 19) 

optimum.solve()

print("decision variable values")

for variable in optimum.variables():
    print(variable.name, "=", variable.varValue)
    
print("\nmax:")
pulp.value(optimum.objective) 

# Write the problem data to an .lp file
optimum.writeLP("sensit1.lp")


optimum.solve()

print("Status:", pulp.LpStatus[optimum.status])

for v in optimum.variables():
    print(v.name, "=", v.varValue, "\tReduced Cost =", v.dj)

print("objective=", pulp.value(optimum.objective))

print("\nSensitivity Analysis\nConstraint\t\tShadow Price\tSlack")
for name, c in list(optimum.constraints.items()):
    print(name, ":", c, "\t", c.pi, "\t\t", c.slack)
# Out:
# decision variable values
# f1 = 28.0
# f10 = 0.0
# f11 = 0.0
# f12 = 0.0
# f13 = 0.0
# f14 = 0.0
# f15 = 0.0
# f16 = 0.0
# f17 = 0.0
# f18 = 0.0
# f19 = 0.0
# f2 = 4.0
# f20 = 0.0
# f21 = 0.0
# f22 = 0.0
# f23 = 0.0
# f24 = 0.0
# f25 = 27.0
# f3 = 20.0
# f4 = 57.0
# f5 = 21.0
# f6 = 52.0
# f7 = 16.0
# f8 = 0.0
# f9 = 0.0
# m1 = 85.0
# m10 = 50.0
# m11 = 30.0
# m12 = 72.0
# m13 = 22.0
# m14 = 20.0
# m15 = 75.0
# m16 = 20.0
# m17 = 72.0
# m18 = 29.0
# m19 = 75.0
# m2 = 35.0
# m20 = 10.0
# m21 = 40.0
# m22 = 40.0
# m23 = 40.0
# m24 = 18.0
# m25 = 20.0
# m26 = 20.0
# m27 = 12.0
# m28 = 55.0
# m3 = 36.0
# m4 = 28.0
# m5 = 60.0
# m6 = 32.0
# m7 = 40.0
# m8 = 40.0
# m9 = 100.0
# y1 = 12.0
# y2 = 2.0
# y3 = 1.0
# y4 = 3.0
# y5 = 29.0
# y6 = 7.0
#
# max:
# Status: Optimal
# f1 = 28.0 	Reduced Cost = 0.0
# f10 = 0.0 	Reduced Cost = 0.0
# f11 = 0.0 	Reduced Cost = 0.0
# f12 = 0.0 	Reduced Cost = 0.0
# f13 = 0.0 	Reduced Cost = 0.0
# f14 = 0.0 	Reduced Cost = 0.0
# f15 = 0.0 	Reduced Cost = 0.0
# ...
